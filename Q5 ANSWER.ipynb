# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
df_re_names=pd.read_csv("C:/PATRICIA/Ironhack/Projects/PROJECT-2/PROJECT-II/df_re_names")
rare_earth_df=pd.read_csv("C:/PATRICIA/Ironhack/Projects/PROJECT-2/PROJECT-II/rare_earth_df_sorted.csv")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <u>QUESTION 5: TOP 10 PROJECTS IN USD</u>

# %%
df_re_names.sample()
# Out:
#     Unnamed: 0.1  Unnamed: 0  Project No.  Deposit No.         Company Name  \
# 89            89          89           90         76.0  ThreeArc Mining LLC
#
#    Project Name                          Location Continent Deposit type  \
# 89       Tomtor  Sakha Republic (Yakutia), Russia      Asia  Carbonatite
#
#     Resource (*10^4 t, REO, Total)  Grade (wt. %)  Lanthanum_Oxide  \
# 89                          323.29          11.99            23.26
#
#     Cerium_Oxide  Praseodymium_Oxide  Neodymium_Oxide  Samarium_Oxide  \
# 89         45.51                4.57            15.21            1.81
#
#     Europium_Oxide  Gadolinium_Oxide  Terbium_Oxide  Dysprosium_Oxide  \
# 89            0.53              1.44           0.19              0.99
#
#     Holmium_Oxide  Erbium_Oxide  Thulium_oxide  Ytterbium_oxide  \
# 89           0.18          0.43           0.05             0.41
#
#     Lutetium_oxide  Yttrium_Oxide  HREE percentage  \
# ...

# %%
rare_earth_df.sample()
# Out:
#     Unnamed: 0             name   units  average_price          date
# 18           0  Lanthanum_Oxide  USD/mt         599.04  Oct 27, 2023

# %%
q5_df_re = df_re_names.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'Project No.', 'Deposit No.',
       'Company Name','Deposit type', 'HREE percentage',
       'REE pattern Ref.', 'Project and status Ref.', 'Deposit type Ref.',
       'Resource and grade Ref.', 'Unnamed: 30' ])

# %%
q5_df_re=q5_df_re.dropna(subset=["Resource (*10^4 t, REO, Total)"])

# %%
q5_df_re.sample()
# Out:
#      Project Name                                           Location  \
# 73  Diamond Creek  Eureka Mining district, the town Salmon, Idaho...
#
#         Continent  Resource (*10^4 t, REO, Total)  Grade (wt. %)  \
# 73  North America                            7.08           1.22
#
#     Lanthanum_Oxide  Cerium_Oxide  Praseodymium_Oxide  Neodymium_Oxide  \
# 73              NaN           NaN                 NaN              NaN
#
#     Samarium_Oxide  Europium_Oxide  Gadolinium_Oxide  Terbium_Oxide  \
# 73             NaN             NaN               NaN            NaN
#
#     Dysprosium_Oxide  Holmium_Oxide  Erbium_Oxide  Thulium_oxide  \
# 73               NaN            NaN           NaN            NaN
#
#     Ytterbium_oxide  Lutetium_oxide  Yttrium_Oxide
# 73              NaN             NaN            NaN

# %%
q5_df_re.columns
# Out:
# Index(['Project Name', 'Location', 'Continent',
#        'Resource (*10^4 t, REO, Total)', 'Grade (wt. %)', 'Lanthanum_Oxide',
#        'Cerium_Oxide', 'Praseodymium_Oxide', 'Neodymium_Oxide',
#        'Samarium_Oxide', 'Europium_Oxide', 'Gadolinium_Oxide', 'Terbium_Oxide',
#        'Dysprosium_Oxide', 'Holmium_Oxide', 'Erbium_Oxide', 'Thulium_oxide',
#        'Ytterbium_oxide', 'Lutetium_oxide', 'Yttrium_Oxide'],
#       dtype='object')

# %%
q5_df_re['Lanthanum_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Lanthanum_Oxide']/100)

# %%
q5_df_re['Cerium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Cerium_Oxide']/100)

# %%
q5_df_re['Praseodymium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Praseodymium_Oxide']/100)

# %%
q5_df_re['Neodymium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Neodymium_Oxide']/100)

# %%
q5_df_re['Samarium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Samarium_Oxide']/100)

# %%
q5_df_re['Europium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Europium_Oxide']/100)

# %%
q5_df_re['Gadolinium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Gadolinium_Oxide']/100)

# %%
q5_df_re['Terbium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Terbium_Oxide']/100)

# %%
q5_df_re['Dysprosium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Dysprosium_Oxide']/100)

# %%
q5_df_re['Holmium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Holmium_Oxide']/100)

# %%
q5_df_re['Erbium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Erbium_Oxide']/100)

# %%
q5_df_re['Thulium_oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Thulium_oxide']/100)

# %%
q5_df_re['Ytterbium_oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Ytterbium_oxide']/100)

# %%
q5_df_re['Lutetium_oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Lutetium_oxide']/100)

# %%
q5_df_re['Yttrium_Oxide'] = ((q5_df_re['Resource (*10^4 t, REO, Total)']*q5_df_re['Grade (wt. %)'])/100)*(q5_df_re['Yttrium_Oxide']/100)

# %%
q5_df_re.sample()
# Out:
#            Project Name          Location Continent  \
# 92  Lovozersky/Lovozero  Murmansk, Russia    Europe
#
#     Resource (*10^4 t, REO, Total)  Grade (wt. %)  Lanthanum_Oxide  \
# 92                           717.4           1.12          2.00872
#
#     Cerium_Oxide  Praseodymium_Oxide  Neodymium_Oxide  Samarium_Oxide  \
# 92       4.01744            0.401744         1.205232        0.056244
#
#     Europium_Oxide  Gadolinium_Oxide  Terbium_Oxide  Dysprosium_Oxide  \
# 92        0.007231          0.048209            0.0          0.048209
#
#     Holmium_Oxide  Erbium_Oxide  Thulium_oxide  Ytterbium_oxide  \
# 92       0.056244      0.064279       0.008035          0.01607
#
#     Lutetium_oxide  Yttrium_Oxide
# 92        0.012052       0.104453

# %%
rare_earth_df.sample()
# Out:
#     Unnamed: 0            name   units  average_price          date
# 16           6  Samarium_Oxide  USD/mt        2089.66  Oct 27, 2023

# %%
prices_dic=dict(zip(rare_earth_df["name"],rare_earth_df["average_price"]))

# %%
prices_dic
# Out:
# {'Terbium_Oxide': 1135380.0,
#  'Scandium_oxide': 891590.0,
#  'Lutetium_oxide': 773170.0,
#  'Dysprosium_Oxide': 369870.0,
#  'Holmium_Oxide': 81496.75,
#  'Neodymium_Oxide': 72998.8,
#  'Praseodymium_Oxide': 72789.84,
#  'Praseodymium-neodymium_oxide': 71257.42,
#  'High_purity_gadolinium_oxide': 41096.65,
#  'Erbium_Oxide': 40051.82,
#  'Gadolinium_Oxide': 38171.13,
#  'Europium_Oxide': 27170.0,
#  'Ytterbium_oxide': 13931.07,
#  'Yttrium_Oxide': 6268.98,
#  'High_Purity_Cerium_Oxide': 2925.52,
#  'High_Purity_lanthanum_Oxide': 2646.9,
#  'Samarium_Oxide': 2089.66,
#  'Cerium_Oxide': 696.55,
#  'Lanthanum_Oxide': 599.04}

# %%
q5_nonull=q5_df_re.dropna(axis=0, how='all')

# %%
q5_nonull
# Out:
#                                           Project Name  \
# 0                                           Mount Weld
# 1                                        Mountain Pass
# 2                                              Eneabba
# 4                                       Dubbo (Toongi)
# 5    Kvanefjeld (Ilimaussaq:Kvanefjeld, Zone 3, Sør...
# ..                                                 ...
# 141                                            Dalucao
# 142                                           Yangfang
# 143                                         Maoniuping
# 144                                          Muluozhai
# 145                        South China seven proveince
#
#                                        Location      Continent  \
# 0                         Mount Weld, Australia      Australia
# 1    Central Mojave Desert, California, America  North America
# 2         Eneabba, Western Australia, Australia      Australia
# ...

# %%
q5_nonull.isna().sum()
# Out:
# Project Name                       0
# Location                           0
# Continent                          0
# Resource (*10^4 t, REO, Total)     0
# Grade (wt. %)                      2
# Lanthanum_Oxide                   15
# Cerium_Oxide                      15
# Praseodymium_Oxide                15
# Neodymium_Oxide                   15
# Samarium_Oxide                    16
# Europium_Oxide                    17
# Gadolinium_Oxide                  17
# Terbium_Oxide                     16
# Dysprosium_Oxide                  17
# Holmium_Oxide                     18
# Erbium_Oxide                      18
# Thulium_oxide                     18
# Ytterbium_oxide                   17
# Lutetium_oxide                    18
# Yttrium_Oxide                     16
# dtype: int64

# %%
q5_nonull = q5_nonull.fillna(0)

# %%
q5_nonull.isna().sum()
# Out:
# Project Name                      0
# Location                          0
# Continent                         0
# Resource (*10^4 t, REO, Total)    0
# Grade (wt. %)                     0
# Lanthanum_Oxide                   0
# Cerium_Oxide                      0
# Praseodymium_Oxide                0
# Neodymium_Oxide                   0
# Samarium_Oxide                    0
# Europium_Oxide                    0
# Gadolinium_Oxide                  0
# Terbium_Oxide                     0
# Dysprosium_Oxide                  0
# Holmium_Oxide                     0
# Erbium_Oxide                      0
# Thulium_oxide                     0
# Ytterbium_oxide                   0
# Lutetium_oxide                    0
# Yttrium_Oxide                     0
# dtype: int64

# %%
q5_df_re.columns
# Out:
# Index(['Project Name', 'Location', 'Continent',
#        'Resource (*10^4 t, REO, Total)', 'Grade (wt. %)', 'Lanthanum_Oxide',
#        'Cerium_Oxide', 'Praseodymium_Oxide', 'Neodymium_Oxide',
#        'Samarium_Oxide', 'Europium_Oxide', 'Gadolinium_Oxide', 'Terbium_Oxide',
#        'Dysprosium_Oxide', 'Holmium_Oxide', 'Erbium_Oxide', 'Thulium_oxide',
#        'Ytterbium_oxide', 'Lutetium_oxide', 'Yttrium_Oxide'],
#       dtype='object')

# %%
q5_nonull['value']=(q5_nonull['Lanthanum_Oxide']*prices_dic['Lanthanum_Oxide'])+(q5_nonull['Cerium_Oxide']*prices_dic['Cerium_Oxide'])+(q5_nonull['Praseodymium_Oxide']*prices_dic['Praseodymium_Oxide'])+(q5_nonull['Neodymium_Oxide']*prices_dic['Neodymium_Oxide'])+(q5_nonull['Samarium_Oxide']*prices_dic['Samarium_Oxide'])+(q5_nonull['Europium_Oxide']*prices_dic['Europium_Oxide'])+(q5_nonull['Gadolinium_Oxide']*prices_dic['Gadolinium_Oxide'])+(q5_nonull['Dysprosium_Oxide']*prices_dic['Dysprosium_Oxide'])+(q5_nonull['Holmium_Oxide']*prices_dic['Holmium_Oxide'])+(q5_nonull['Erbium_Oxide']*prices_dic['Erbium_Oxide'])+(q5_nonull['Ytterbium_oxide']*prices_dic['Ytterbium_oxide'])+(q5_nonull['Lutetium_oxide']*prices_dic['Lutetium_oxide'])+(q5_nonull['Yttrium_Oxide']*prices_dic['Yttrium_Oxide'])

# %%
q5_nonull.head(3)
# Out:
#     Project Name                                    Location      Continent  \
# 0     Mount Weld                       Mount Weld, Australia      Australia
# 1  Mountain Pass  Central Mojave Desert, California, America  North America
# 2        Eneabba       Eneabba, Western Australia, Australia      Australia
#
#    Resource (*10^4 t, REO, Total)  Grade (wt. %)  Lanthanum_Oxide  \
# 0                          300.00           5.40         3.906164
# 1                          418.30           8.90        12.360427
# 2                            7.29           0.09         0.001531
#
#    Cerium_Oxide  Praseodymium_Oxide  Neodymium_Oxide  Samarium_Oxide  \
# 0      7.397260            0.821918         2.928082        0.408904
# 1     18.279825            1.598918         4.467898        0.300506
# 2      0.003005            0.000267         0.000933        0.000164
#
#    Europium_Oxide  Gadolinium_Oxide  Terbium_Oxide  Dysprosium_Oxide  \
# ...

# %%
q5_nonull['value(M$)']=q5_nonull['value']/100

# %%
q5_nonull.head(3)
# Out:
#     Project Name                                    Location      Continent  \
# 0     Mount Weld                       Mount Weld, Australia      Australia
# 1  Mountain Pass  Central Mojave Desert, California, America  North America
# 2        Eneabba       Eneabba, Western Australia, Australia      Australia
#
#    Resource (*10^4 t, REO, Total)  Grade (wt. %)  Lanthanum_Oxide  \
# 0                          300.00           5.40         3.906164
# 1                          418.30           8.90        12.360427
# 2                            7.29           0.09         0.001531
#
#    Cerium_Oxide  Praseodymium_Oxide  Neodymium_Oxide  Samarium_Oxide  \
# 0      7.397260            0.821918         2.928082        0.408904
# 1     18.279825            1.598918         4.467898        0.300506
# 2      0.003005            0.000267         0.000933        0.000164
#
#    Europium_Oxide  Gadolinium_Oxide  Terbium_Oxide  Dysprosium_Oxide  \
# ...

# %%
q5_nonull.columns
# Out:
# Index(['Project Name', 'Location', 'Continent',
#        'Resource (*10^4 t, REO, Total)', 'Grade (wt. %)', 'Lanthanum_Oxide',
#        'Cerium_Oxide', 'Praseodymium_Oxide', 'Neodymium_Oxide',
#        'Samarium_Oxide', 'Europium_Oxide', 'Gadolinium_Oxide', 'Terbium_Oxide',
#        'Dysprosium_Oxide', 'Holmium_Oxide', 'Erbium_Oxide', 'Thulium_oxide',
#        'Ytterbium_oxide', 'Lutetium_oxide', 'Yttrium_Oxide', 'value',
#        'value(M$)'],
#       dtype='object')

# %%
q5_subset=q5_nonull[['Location', 'Continent','value(M$)']]

# %%
q5_subset_5= q5_subset.head(5)

# %%
q5_sorted = q5_subset_5.sort_values(by="value(M$)", ascending=False)

# %%
Poject_value =sns.barplot(y=q5_sorted["value(M$)"],x=q5_sorted["Location"], palette="Set3",legend=False, data=q5_sorted)
Poject_value.legend(loc='upper right', bbox_to_anchor=(0.6, 1), title="project value")
plt.ylabel("value in M USD")
Poject_value.set_xticklabels(Poject_value.get_xticklabels(), rotation=45, horizontalalignment='right');
# Out:
# C:\Users\psaez\AppData\Local\Temp\ipykernel_19220\3206439733.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   Poject_value =sns.barplot(y=q5_sorted["value(M$)"],x=q5_sorted["Location"], palette="Set3",legend=False, data=q5_sorted)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\psaez\AppData\Local\Temp\ipykernel_19220\3206439733.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Poject_value.set_xticklabels(Poject_value.get_xticklabels(), rotation=45, horizontalalignment='right');

# %%
q5_answer
# Out:
#                                       Location      Continent    value(M$)
# 0                        Mount Weld, Australia      Australia  3250.584759
# 1   Central Mojave Desert, California, America  North America  4788.853831
# 2        Eneabba, Western Australia, Australia      Australia     1.244600
# 4            Dubbo, New South Wales, Australia      Australia   102.004443
# 5                            Narsaq, Greenland      Greenland  2382.050053
# 7                             Longonjo, Angola         Africa  1276.861797
# 10                         Kujalleq, Greenland      Greenland  5154.955580
# 11                Gränna, south central sweden         Europe    38.646317
# 12                        south central sweden         Europe     9.681264
# 13                             southern norway         Europe   702.580478
